# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv('apis.env')

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

type(nyt_api_key)
type(tmdb_api_key)
# Out:
# str

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
query_url = (
    f"{url}api-key={nyt_api_key}&begin_date={begin_date}&end_date={end_date}"
    + f'&fq={filter_query}&sort={sort}&fl={field_list}'
)

response_data = requests.get(query_url)
response_data
query_url
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=cLyGcQ1xu4ZT1J6n2JnTaH7C7XOtuJ6C&begin_date=20130101&end_date=20230531&fq=section_name:"Movies" AND type_of_material:"Review" AND headline:"love"&sort=newest&fl=headline,web_url,snippet,source,keywords,pub_date,byline,word_count'

# %%
# Create an empty list to store the reviews
reviews_list = []

# loop through pages 0-19
for page in range(20):
 
    # create query with a page number
    # API results show 10 articles at a time
    query_url = (
    f"{url}api-key={nyt_api_key}&begin_date={begin_date}&end_date={end_date}"
    + f'&fq={filter_query}&sort={sort}&fl={field_list}&page={page}'
    )
    try: 
    # Make a "GET" request and retrieve the JSON
        response = requests.get(query_url)
        reviews = response.json()    


    # Add a twelve second interval between queries to stay within API query limits
        time.sleep(12)
        
    # Try and save the reviews to the reviews_list
        # loop through the reviews["response"]["docs"] and append each review to the list
        reviews_list.extend(reviews['response']['docs'])
        print(f"Page {page + 1} fetched successfully.")
        
        # Print the page that was just retrieved
        print(f"Page {page + 1} retrieved")
        print(f"Total reviews retrieved: {len(reviews_list)}")
        # Print the page number that had no results then break from the loop
    except Exception as e:
        print(f"Failed at page {page + 1}: {str(e)}")
        break
# Out:
# Page 1 fetched successfully.
# Page 1 retrieved
# Total reviews retrieved: 10
# Page 2 fetched successfully.
# Page 2 retrieved
# Total reviews retrieved: 20
# Page 3 fetched successfully.
# Page 3 retrieved
# Total reviews retrieved: 30
# Page 4 fetched successfully.
# Page 4 retrieved
# Total reviews retrieved: 40
# Page 5 fetched successfully.
# Page 5 retrieved
# Total reviews retrieved: 50
# Page 6 fetched successfully.
# Page 6 retrieved
# Total reviews retrieved: 60
# Page 7 fetched successfully.
# Page 7 retrieved
# Total reviews retrieved: 70
# Page 8 fetched successfully.
# Page 8 retrieved
# Total reviews retrieved: 80
# Page 9 fetched successfully.
# Page 9 retrieved
# Total reviews retrieved: 90
# Page 10 fetched successfully.
# Page 10 retrieved
# Total reviews retrieved: 100
# Page 11 fetched successfully.
# Page 11 retrieved
# Total reviews retrieved: 110
# Page 12 fetched successfully.
# Page 12 retrieved
# Total reviews retrieved: 120
# ...

# %%
print(f"Total reviews collected: {len(reviews_list)}")
# Out:
# Total reviews collected: 200

# %%
print(json.dumps(reviews_list[:5], indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
# ...

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(reviews_list[:5], indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
# ...

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
df_reviews = pd.json_normalize(reviews_list)
df_reviews
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# ...

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early

df_reviews['title'] = df_reviews['headline.main'].apply(lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")])

titles = df_reviews['title'].tolist()

titles
# Out:
# ['The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'About Fate',
#  'Waiting for Bojangles',
#  'I Love My Dad',
#  'A Love Song',
#  'Alone Together',
#  'Art of Love',
#  'The Wheel',
#  'Thor: Love and Thunder',
#  'Both Sides of the Blade',
#  'Fire of Love',
#  'Love & Gelato',
#  'Stay Prayed Up',
#  'Benediction',
#  'Dinner in America',
#  'In a New York Minute',
#  'Anaïs in Love',
#  'I Love America',
#  'See You Then',
#  'La Mami',
#  'Love After Love',
#  'Deep Water',
#  'Lucy and Desi',
# ...

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keywords_list):
    return ', '.join([f"{keyword['name']}: {keyword['value']}" for keyword in keywords_list])


# Fix the "keywords" column by converting cells from a list to a string
df_reviews['keywords'] = df_reviews['keywords'].apply(extract_keywords)

keywords = df_reviews['keywords'].tolist()
print(keywords[:5])
# Out:
# ['subject: Movies, creative_works: The Attachment Diaries (Movie), persons: Diment, Valentin Javier', 'subject: Movies, persons: Kapur, Shekhar, persons: James, Lily, persons: Azmi, Shabana, persons: Thompson, Emma', "subject: Movies, creative_works: You Can Live Forever (Movie), persons: Slutsky, Mark, persons: Watts, Sarah (Film Director), persons: O'Driscoll, Anwen, persons: Laporte, June (Actor)", "subject: Movies, creative_works: A Tourist's Guide to Love (Movie), persons: Tsuchida, Steven, persons: Cook, Rachael Leigh", "subject: Movies, persons: Zlotowski, Rebecca, creative_works: Other People's Children (Movie)"]

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
titles = df_reviews['title'].tolist()
print(titles[:5])
# Out:
# ['The Attachment Diaries', 'What’s Love Got to Do With It?’ Probably a Lo', 'You Can Live Forever', 'A Tourist’s Guide to Love', 'Other People’s Children']

# %% [markdown]
# ### Access The Movie Database API

# %%
import requests

url = "https://api.themoviedb.org/3/authentication"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjZTdiOWNiNzg5OWM2Mjg2YTA0MWZmMDQ3YTRjMjk0MiIsInN1YiI6IjY2MWYwYjdhNmEzMDBiMDE0YjMyMzc2OCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.5CIvLaF1sMXQfmJRWUxXINey3_TyRDGtr9mcfexMHdo"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"success":true,"status_code":1,"status_message":"Success."}

# %%
# Prepare The Movie Database query
tmdb_base_url = "https://api.themoviedb.org/3/"
tmdb_url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = f"&api_key={tmdb_api_key}"

# Search for reviews published between a begin and end date
query = "Jack"

# Build URL

search_url = (f"{tmdb_base_url}search/movie?query={query}&api_key={tmdb_api_key}")

response_data = requests.get(search_url)
response_data
search_url
# Out:
# 'https://api.themoviedb.org/3/search/movie?query=Jack&api_key=ce7b9cb7899c6286a041ff047a4c2942'

# %%
tmdb_url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = f"&api_key={tmdb_api_key}"
include_adult = f"&include_adult={'false'}"

# %%
# Create an empty list to store the results
tmdb_movies_list = []

# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 0

# Loop through the titles
for title in titles:
    search_query = f"{tmdb_url}{title}{tmdb_key_string}{include_adult}"
    response = requests.get(search_query)
    search_results = response.json()
    # print(search_query)
    # Check if we need to sleep before making a request
    if request_counter % 50 == 0:
        time.sleep(1)

    # Add 1 to the request counter
    request_counter +=1
    
    # Perform a "GET" request for The Movie Database
    try:
    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.

        # Get movie id
        movie_id = search_results['results'][0]['id']
        # Make a request for a the full movie details
        movie_query = f"https://api.themoviedb.org/3/movie/{movie_id}?{tmdb_key_string}"
        movie_response = requests.get(movie_query)
        movie_details = movie_response.json()


        # Execute "GET" request with url
        details_reposonse = requests.get(details_url)
        movie_details = details_reposonse.json()
        
        # Extract the genre names into a list
        genres = [genre['name'] for genre in movie_details['genres']]

        # Extract the spoken_languages' English name into a list
        spoken_languages = [lang['english_name'] for lang in movie_details.get('spoken_languages', [])]


        # Extract the production_countries' name into a list
        production_countries = [country['name'] for country in movie_details.get('production_countries', [])]


        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list
        movie_dict = {
            'title': movie_details['title'],
            'original_title': movie_details['original_title'],
            'budget': movie_details['budget'],
            'original_language': movie_details['original_language'],
            'overview': movie_details['overview'],
            'popularity': movie_details['popularity'],
            'runtime': movie_details['runtime'],
            'revenue': movie_details['revenue'],
            'release_date': movie_details['release_date'],
            'vote_average': movie_details['vote_average'],
            'vote_count': movie_details['vote_count'],
            'genres': genres,
            'spoken_languages': spoken_languages,
            'production_countries': production_countries
        }
        tmdb_movies_list.append(movie_dict)
        print(f"Added details for: {title}")
        
        # Print out the title that was found
    except IndexError:
        print(f"No results found for {title}")
# Out:
# https://api.themoviedb.org/3/search/movie?query=The Attachment Diaries&api_key=ce7b9cb7899c6286a041ff047a4c2942&include_adult=false
# Added details for: The Attachment Diaries
# https://api.themoviedb.org/3/search/movie?query=What’s Love Got to Do With It?’ Probably a Lo&api_key=ce7b9cb7899c6286a041ff047a4c2942&include_adult=false
# No results found for What’s Love Got to Do With It?’ Probably a Lo
# https://api.themoviedb.org/3/search/movie?query=You Can Live Forever&api_key=ce7b9cb7899c6286a041ff047a4c2942&include_adult=false
# Added details for: You Can Live Forever
# https://api.themoviedb.org/3/search/movie?query=A Tourist’s Guide to Love&api_key=ce7b9cb7899c6286a041ff047a4c2942&include_adult=false
# Added details for: A Tourist’s Guide to Love
# https://api.themoviedb.org/3/search/movie?query=Other People’s Children&api_key=ce7b9cb7899c6286a041ff047a4c2942&include_adult=false
# Added details for: Other People’s Children
# ...

# %%
print(search_results)

# %%
tmdb_movies_list

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(tmdb_movies_list[:5], indent=4))
# Out:
# [
#     {
#         "title": "The Three Musketeers: Milady",
#         "original_title": "Les trois mousquetaires : Milady",
#         "budget": 39000000,
#         "original_language": "fr",
#         "overview": "D'Artagnan, on a quest to rescue the abducted Constance, runs into the mysterious Milady de Winter again. The tension between the Catholics and the Protestants finally escalates, as the king declares war \u2014 forcing the now four musketeers into battle. But as the war goes on, they are tested physically, mentally and emotionally.",
#         "popularity": 1058.901,
#         "runtime": 121,
#         "revenue": 20888270,
#         "release_date": "2023-12-13",
#         "vote_average": 6.593,
#         "vote_count": 317,
#         "genres": [
#             "Adventure",
#             "Action",
#             "Drama"
#         ],
#         "spoken_languages": [
#             "French"
#         ],
#         "production_countries": [
#             "Belgium",
# ...

# %%
# Convert the results to a DataFrame
tmdb_df = pd.DataFrame(tmdb_movies_list)
tmdb_df
# Out:
#                             title                    original_title    budget  \
# 0    The Three Musketeers: Milady  Les trois mousquetaires : Milady  39000000
# 1    The Three Musketeers: Milady  Les trois mousquetaires : Milady  39000000
# 2    The Three Musketeers: Milady  Les trois mousquetaires : Milady  39000000
# 3    The Three Musketeers: Milady  Les trois mousquetaires : Milady  39000000
# 4    The Three Musketeers: Milady  Les trois mousquetaires : Milady  39000000
# ..                            ...                               ...       ...
# 149  The Three Musketeers: Milady  Les trois mousquetaires : Milady  39000000
# 150  The Three Musketeers: Milady  Les trois mousquetaires : Milady  39000000
# 151  The Three Musketeers: Milady  Les trois mousquetaires : Milady  39000000
# 152  The Three Musketeers: Milady  Les trois mousquetaires : Milady  39000000
# 153  The Three Musketeers: Milady  Les trois mousquetaires : Milady  39000000
#
# ...

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
df_reviews
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# ...

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
merged_df = pd.merge(df_reviews, tmdb_df, on='title', how='inner')
merged_df
# Out:
# Empty DataFrame
# Columns: [web_url, snippet, source, keywords, pub_date, word_count, headline.main, headline.kicker, headline.content_kicker, headline.print_headline, headline.name, headline.seo, headline.sub, byline.original, byline.person, byline.organization, title, original_title, budget, original_language, overview, popularity, runtime, revenue, release_date, vote_average, vote_count, genres, spoken_languages, production_countries]
# Index: []
#
# [0 rows x 30 columns]

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
columns_to_fix = ['genres', 'spoken_languages', 'production_countries']

# Create a list of characters to remove
characters_to_remove = ["[", "]", "'"]

# Loop through the list of columns to fix
for col in columns_to_fix:
    # Convert the column to type 'str'
    merged_df[col] = merged_df[col].astype(str)

    # Loop through characters to remove
    for char in characters_to_remove:
        merged_df[col] = merged_df[col].str.replace(char, '')

# Display the fixed DataFrame
print(merged_df)
# Out:
# Empty DataFrame
# Columns: [web_url, snippet, source, keywords, pub_date, word_count, headline.main, headline.kicker, headline.content_kicker, headline.print_headline, headline.name, headline.seo, headline.sub, byline.original, byline.person, byline.organization, title, original_title, budget, original_language, overview, popularity, runtime, revenue, release_date, vote_average, vote_count, genres, spoken_languages, production_countries]
# Index: []
#
# [0 rows x 30 columns]

# %%
# Drop "byline.person" column
merged_df.drop(columns=['byline.person'], inplace=True)

# %%
merged_df.drop_duplicates(inplace=True)
# Out:
# Empty DataFrame
# Columns: [web_url, snippet, source, keywords, pub_date, word_count, headline.main, headline.kicker, headline.content_kicker, headline.print_headline, headline.name, headline.seo, headline.sub, byline.original, byline.organization, title, original_title, budget, original_language, overview, popularity, runtime, revenue, release_date, vote_average, vote_count, genres, spoken_languages, production_countries]
# Index: []
#
# [0 rows x 29 columns]

# %%
# Delete duplicate rows and reset index
merged_df.drop_duplicates(inplace=True)
# Out:
#                             title                  original_title  budget  \
# 0          The Attachment Diaries                        El apego       0
# 1            You Can Live Forever            You Can Live Forever       0
# 2                  One True Loves                  One True Loves       0
# 3  The Lost Weekend: A Love Story  The Lost Weekend: A Love Story       0
# 4              A Thousand and One              A Thousand and One       0
#
#                               genre language spoken_languages  \
# 0  Drama, Mystery, Thriller, Horror       es          Spanish
# 1                    Drama, Romance       en  French, English
# 2            Romance, Drama, Comedy       en          English
# 3                       Documentary       en
# 4                             Drama       en          English
#
#                                             homepage  \
# 0
# 1  https://gooddeedentertainment.com/you-can-live...
# 2
# 3
# ...

# %%
# Export data to CSV without the index
merged_df.to_csv('merged_data.csv', index=False)
